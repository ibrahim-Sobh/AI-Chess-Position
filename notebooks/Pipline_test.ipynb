# %%
# %load_ext autoreload
# %autoreload 2
import sys
if not ".." in sys.path:
    sys.path.append('..')
if not "../../" in sys.path:
    sys.path.append('../../')

# %%
from app.generator import generate_random_image_from_FEN
from app.inference import make_prediction

# %%
image  = generate_random_image_from_FEN('5bnr/pp4pp/pppppppp/8/8/8/5PPP/8')

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img  = mpimg.imread(image)
plt.imshow(img)

# %%
result = make_prediction(image)
print(result)
# Out:
# 2/2 [==============================] - 0s 3ms/step
# 5bnr-pp4pp-pppppppp-8-8-8-5PPP-8
# 2022-08-04 23:51:08.499862: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
predicted_image  = generate_random_image_from_FEN(result.replace('-','/'),optional_path='../random/prediction_')

# %%
pred_img  = mpimg.imread(predicted_image)
plt.imshow(pred_img)
